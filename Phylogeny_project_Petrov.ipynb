# %%
from IPython.display import Image

# %% [markdown]
# # Ген миозин у S.cerevisiae
#
# ## Данные:

# %%
Myo_seq_10 = '/phylogeny_project/myo.fasta' # 10 последовательностей ортологов

# %% [markdown]
# ## Выравнивание:
#
# Алгоритмы CLUSTAL OMEGA/MAFFT/MUSCLE
#
# Выбран Muscle

# %%
Alignment_muscle = '/phylogeny_project/myo_alignment.fasta'

# %% [markdown]
# ## Gblocks

# %% [markdown]
# Запуск со стандартными параметрами

# %%
Cured_alignment = '/phylogeny_project/cured_myo_alignment.fasta'

# %% [markdown]
# ## jModelTest2

# %% [markdown]
# Лучшие модели:
#
# 1. TVMef+G
# 2. TVMef+I+G
# 3. SYM+I+G

# %% [markdown]
# ## NJ tree

# %%
Image('NJ_tree.png')

# %% [markdown]
# ## IQ tree

# %% [markdown]
# #### TVMe model

# %%
Image('iq_1.png')

# %% [markdown]
# #### SYM model

# %%
Image('iq_2.png')

# %% [markdown]
# #### Auto model

# %%
Image('iq_3.png')

# %% [markdown]
# ## Bayes tree

# %%
Image('Bayes_tree.png')
